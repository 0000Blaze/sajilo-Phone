# %%
import pandas as pd
data = pd.read_excel('rawData.xlsx')
data.head()
# Out:
#                           Unnamed: 0      Unnamed: 1  Unnamed: 2  \
# 0              sajilophone@gmail.com             NaN         NaN
# 1    Rural Municipality/Municipality          Phone          NaN
# 2                         Taplejung            Mayor         NaN
# 3              Fungling Municipality      Amir maden  9842660480
# 4  Athrai Tribeni Rural Municipality  Dipendra Pomu   9852660958
#
#                 Unnamed: 3    Unnamed: 4                Unnamed: 5  \
# 0                      NaN           NaN                       NaN
# 1                      NaN           NaN                       NaN
# 2             Deputy Mayor           NaN  Chief Executive Officer
# 3          Bhima Devi Ojha  9.852660e+09            Tilochan Rimal
# 4  Shantakumari Angbuhang   9.842659e+09              Bijay Ingnam
#
#      Unnamed: 6           Unnamed: 7  Unnamed: 8      Unnamed: 9  ...  \
# 0           NaN                  NaN         NaN             NaN  ...
# ...
